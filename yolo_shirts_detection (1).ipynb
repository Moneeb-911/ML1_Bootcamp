# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR='/content/gdrive/My Drive/shirts_dataset_yolo'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.5 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %%
import os
from ultralytics import YOLO

# %%
model=YOLO('yolov5nu.pt')

# %%
# Assuming you have created a YAML file named 'dataset.
res=model.train(data=os.path.join(ROOT_DIR,'config.yaml'),epochs=50)
# Out:
# Ultralytics YOLOv8.2.68 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model.save('shirts_detection')

# %%
model.val()
# Out:
# Ultralytics YOLOv8.2.68 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv5n summary (fused): 193 layers, 2,503,724 parameters, 0 gradients, 7.1 GFLOPs
# val: Scanning /content/gdrive/My Drive/shirts_dataset_yolo/data/labels.cache... 420 images, 0 backgrounds, 0 corrupt: 100%|██████████| 420/420 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 27/27 [00:10<00:00,  2.51it/s]
#                    all        420        487      0.991      0.993      0.995      0.908
#             Blue shirt         93         93      0.982      0.989      0.994      0.939
#             Gray shirt         73         73      0.986      0.981      0.994      0.919
# ...

# %%
import matplotlib.pyplot as plt

# %%
pic=plt.imread('/content/131.jpg')
res=model.predict(source=pic,save=True)
plt.imshow(res[0].plot())
# Out:
# 0: 640x512 1 Black shirt, 118.0ms
# Speed: 3.0ms preprocess, 118.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 512)
# Results saved to runs/detect/train3

# %%
pic=plt.imread('/content/c4c248f9286724b2586171ffd9187c99.jpg')
res=model.predict(source=pic,save=True)
plt.imshow(res[0].plot())
# Out:
# 0: 640x416 1 Gray shirt, 131.1ms
# Speed: 3.1ms preprocess, 131.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 416)
# Results saved to runs/detect/train4

# %%
pic=plt.imread('/content/images.jpg')
res=model.predict(source=pic,save=True)
plt.imshow(res[0].plot())
# Out:
# 0: 640x640 1 Black shirt, 14.6ms
# Speed: 4.2ms preprocess, 14.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/train5

# %%
pic=plt.imread('/content/images_white.jpg')
res=model.predict(source=pic,save=True)
plt.imshow(res[0].plot())
# Out:
# 0: 640x576 2 White shirts, 414.6ms
# Speed: 3.0ms preprocess, 414.6ms inference, 8.6ms postprocess per image at shape (1, 3, 640, 576)
# Results saved to runs/detect/train6

# %%
pic=plt.imread('/content/johnny.jpg')
res=model.predict(source=pic,save=True)
plt.imshow(res[0].plot())
# Out:
# 0: 640x480 1 White shirt, 59.8ms
# Speed: 4.3ms preprocess, 59.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/train8

# %%
# !pip install numpy
# !pip install opencv-python

# %%
import matplotlib.pyplot as plt
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode
import cv2
from google.colab.patches import cv2_imshow
def take_photo(filename='photo.jpg', quality=0.8):
    js = Javascript('''
    async function takePhoto(quality) {
        const div = document.createElement('div');
        const capture = document.createElement('button');
        capture.textContent = 'Capture';
        div.appendChild(capture);
        const video = document.createElement('video');
        video.style.display = 'block';
        const stream = await navigator.mediaDevices.getUserMedia({video: true});
        document.body.appendChild(div);
        div.appendChild(video);
        video.srcObject = stream;
        await video.play();
        // Resize video to match webcam resolution
        google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);
        // Wait for Capture button to be clicked.
        await new Promise((resolve) => capture.onclick = resolve);
        const canvas = document.createElement('canvas');
        canvas.width = video.videoWidth;
        canvas.height = video.videoHeight;
        canvas.getContext('2d').drawImage(video, 0, 0);
        stream.getVideoTracks()[0].stop();
        div.remove();
        return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
    display(js)
    data = eval_js('takePhoto({})'.format(quality))
    binary = b64decode(data.split(',')[1])
    with open(filename, 'wb') as f:
        f.write(binary)
    return filename
# Take a photo using the webcam
image_path = take_photo()
print(f"Photo saved at {image_path}")
# Load the captured image
img = plt.imread(image_path)
# Perform inference on the captured image
results = model.predict(img, save=True)
# Display the results
results[0].plot() # Use plot() to show the results in Colab
# Out:
# Photo saved at photo.jpg
#
# 0: 480x640 1 Gray shirt, 13.2ms
# Speed: 1.6ms preprocess, 13.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/train5
# array([[[181, 207, 198],
#         [184, 210, 201],
#         [188, 213, 207],
#         ...,
#         [234, 249, 244],
#         [234, 249, 244],
#         [234, 249, 244]],
#
#        [[180, 206, 197],
#         [183, 209, 200],
#         [185, 210, 204],
#         ...,
#         [234, 249, 244],
#         [234, 249, 244],
#         [233, 250, 244]],
#
#        [[184, 211, 202],
#         [185, 212, 203],
#         [186, 213, 206],
#         ...,
#         [233, 250, 244],
#         [233, 250, 244],
#         [231, 250, 244]],
#
#        ...,
#
#        [[128, 130, 119],
#         [130, 134, 120],
#         [128, 131, 120],
#         ...,
#         [152, 138,  74],
#         [169, 155,  61],
#         [235, 219,  11]],
#
#        [[122, 125, 116],
#         [120, 126, 114],
# ...

# %%
pic=plt.imread('/content/images_white.jpg')
res=model.predict(source=pic,save=True)
plt.imshow(res[0].plot())
# Out:
# 0: 640x576 2 White shirts, 368.8ms
# Speed: 3.3ms preprocess, 368.8ms inference, 9.2ms postprocess per image at shape (1, 3, 640, 576)
# Results saved to runs/detect/train29

# %%
pic=plt.imread('/content/WhatsApp Image 2024-07-29 at 10.59.41.jpeg')
res=model.predict(source=pic,save=True)
plt.imshow(res[0].plot())
# Out:
# 0: 640x480 1 Gray shirt, 97.1ms
# Speed: 3.0ms preprocess, 97.1ms inference, 13.9ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/train218

# %%
pic=plt.imread('/content/WhatsApp Image 2024-07-29 at 11.03.36.jpeg')
res=model.predict(source=pic,save=True)
plt.imshow(res[0].plot())
# Out:
# 0: 640x480 1 Gray shirt, 55.5ms
# Speed: 2.8ms preprocess, 55.5ms inference, 10.8ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/train221

# %%
pic=plt.imread('/content/WhatsApp Image 2024-07-29 at 11.07.27.jpeg')
res=model.predict(source=pic,save=True)
plt.imshow(res[0].plot())
# Out:
# 0: 448x640 1 White shirt, 203.6ms
# Speed: 3.7ms preprocess, 203.6ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/train223

# %%
pic=plt.imread('/content/3_2.webp')
res=model.predict(source=pic,save=True)
plt.imshow(res[0].plot())
# Out:
# 0: 640x640 1 Black shirt, 17.9ms
# Speed: 5.4ms preprocess, 17.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/train226

# %%
pic=plt.imread('/content/48-assfmmopd44109-allen-solly-original-imagkc43caqruuzn.webp')
res=model.predict(source=pic,save=True)
plt.imshow(res[0].plot())
# Out:
# 0: 640x448 1 White shirt, 96.9ms
# Speed: 3.5ms preprocess, 96.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to runs/detect/train227

# %%
pic=plt.imread('/content/web_to_jpeg.jpg')
res=model.predict(source=pic,save=True)
plt.imshow(res[0].plot())
# Out:
# 0: 640x544 1 Gray shirt, 13.8ms
# Speed: 7.0ms preprocess, 13.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 544)
# Results saved to runs/detect/train10

# %%
pic=plt.imread('/content/26-1-600x600.jpg')
res=model.predict(source=pic,save=True)
plt.imshow(res[0].plot())
# Out:
# 0: 640x640 1 Gray shirt, 20.7ms
# Speed: 3.5ms preprocess, 20.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/train11

# %%
pic=plt.imread('/content/86f6cca46ca00873a3d34b05aa7577b7.jpg')
res=model.predict(source=pic,save=True)
plt.imshow(res[0].plot())
# Out:
# 0: 640x448 1 Black shirt, 73.8ms
# Speed: 2.6ms preprocess, 73.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to runs/detect/train9
